# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.api as sm
import pickle
# %matplotlib inline

# %%
path = "/labs/mignot/GenRED.II.autosomalClean.Final.mds"

# %%
df = pd.read_csv(path, delim_whitespace=True)
df['FID'] = df['FID'].apply(lambda x: x.split("_")[-1])

# %%
df.head()
# Out:
#       FID                                 IID  SOL        C1        C2  \
# 0  LD0014  WG0117063-DNAA01_8000066550_LD0014    0 -0.003309  0.014030
# 1  LD0041  WG0117063-DNAA02_8000066573_LD0041    0 -0.040239  0.000318
# 2  LD0038  WG0117063-DNAA04_8000066599_LD0038    0  0.006729  0.007246
# 3  LD0084  WG0117063-DNAA05_8000066582_LD0084    0  0.004359 -0.001416
# 4  LD0022  WG0117063-DNAA06_8000066852_LD0022    0  0.004776  0.001741
#
#          C3        C4        C5        C6        C7        C8        C9
# 0  0.007670 -0.003006  0.008063 -0.008303  0.007457 -0.009014  0.009331
# 1 -0.006434 -0.001362 -0.002399 -0.002950 -0.001922 -0.011280  0.004143
# 2 -0.002515  0.004305 -0.000373 -0.007282  0.002509 -0.008408 -0.007790
# 3 -0.015182 -0.009998  0.000340 -0.005163  0.003465  0.004353  0.012437
# 4 -0.000872  0.002636  0.010817  0.010118 -0.002008 -0.005445  0.008797

# %%
PCs = ["C1", "C2", "C3", "C4", "C5", "C6", "C7", "C8", "C9"]

# %%
for i, PC in enumerate(PCs):
    if i != len(PCs)-1:
        fig, ax = plt.subplots()
        sns.scatterplot(PCs[i], PCs[i+1], data=df)

# %%
sns.scatterplot("C1", "C2", data=df)
