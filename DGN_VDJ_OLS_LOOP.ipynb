# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import statsmodels.api as sm
from statsmodels.stats.multitest import fdrcorrection

# %%
# family counts to usage
def family_counts_df_to_usage_df(family_counts_df, drop_families=[]):
    
    # drop any families (so that they are not included in total count)
    if len(drop_families) > 0:
        family_counts_df = family_counts_df[~family_counts_df['family'].isin(drop_families)]

#     # Filter out pseudogenes and non-functional genes
#     valid_TCR_genes = set()
#     with open("valid_TCR_genes.txt", "r") as f:
#         for line in f:
#             valid_TCR_genes.add(line.strip())
#     valid_TCR_genes.add("TRAV8-5")
#     df = df[df['family'].isin(valid_TCR_genes)]
    
    # get total counts for every patient, every family (adding subtype counts together)
    family_counts_df = family_counts_df.groupby(["patid", "family"]).sum().rename(columns={"count":"family_count"}).reset_index()

    # take out the segment (AJ) out of the family (TRAJ1), and groupby patid+segment to get total AJ, total BJ, AV, BV for each patient
    family_counts_df['segment'] = family_counts_df['family'].str.slice(start=2, stop=4)
    segment_counts_df = family_counts_df.groupby(["patid", "segment"]).sum().rename(columns={"family_count":"segment_count"}).reset_index()

    # merge the family count and segment count dfs, allowing us to calculate usage ratio
    df_with_total = pd.merge(family_counts_df, segment_counts_df, how="inner", on=["patid", "segment"])
    df_with_total["usage_ratio"] = df_with_total["family_count"]/df_with_total["segment_count"]
    usage_df = df_with_total[["patid", "family", "usage_ratio"]]

    # make both long and wide formats for the usage_ratio table
    usage_table = usage_df.pivot(index="patid", columns="family", values="usage_ratio").fillna(0)
    usage_table = usage_table.reindex(sorted(usage_table.columns), axis=1).fillna(0)
    usage_table = usage_table.reset_index()

#     # only want patids in Sharon's paper, N=895, due to quality control
#     sharon_counts_df = pd.read_csv("gene_counts.tsv", delimiter="\t")
#     sharon_counts_df = sharon_counts_df.reset_index()
#     sharon_ids = set(sharon_counts_df.columns[1:])
#     usage_table = usage_table[usage_table['patid'].isin(sharon_ids)].set_index("patid")
    return usage_df, usage_table

# %%
def do_ols(pat_info_df, usage_table, ind_var, y_cols, cov_cols):
    # ind_var: independent variable for model, e.g. 'DQB1*03:01'
    all_df = pd.merge(pat_info_df, usage_table, right_index=True, left_index=True, how="inner")
#     if binary: # code variable as 0 1
#         ind_var_col_name = "{}_binary".format(ind_var)
#         all_df[ind_var_col_name] = (all_df[ind_var] > 0).astype("float")
#     else: # code variable as 0 1 2
    ind_var_col_name = ind_var
    #all_df[ind_var_col_name] = all_df[ind_var_col_name].astype("float")
    
    print("doing {} tests. out of {} rows, {} are {} > 0".format(len(y_cols), len(all_df), len(all_df[all_df[ind_var]>0]), ind_var))
    x_columns = [ind_var_col_name] + cov_cols
    res_df = pd.DataFrame()
    for y_column in y_cols:
        X = all_df[x_columns]
        y = all_df[y_column]
        X = sm.add_constant(X) # constant is always added
        mod = sm.OLS(y, X)
        res = mod.fit()
        #print(res.summary())
        tcr_df = pd.DataFrame()
        tcr_df['coef'] = res.params
        tcr_df['se'] = res.bse
        tcr_df['pvalue'] = res.pvalues
        tcr_df['tvalue'] = res.tvalues
        res_df[y_column] = tcr_df.loc[ind_var_col_name]

    res_df = res_df.transpose().reset_index().rename(columns={"index":"TCR"}).sort_values("pvalue", ascending=True)
    # FDR correction
    res_df['pvalue_fdr'] = fdrcorrection(res_df['pvalue'])[1]
    return res_df

# %%
def do_stepwise_ols(HLA_df, counts_df, cov_df, ind_var, cov_cols, want_families={}, fdr=True):
    
    def is_continue(df):
        if len(want_families) > 0: # need results for all families in want_families
            print(set(df['TCR']).intersection(want_families), want_families)
            if set(df['TCR']).intersection(want_families) == want_families:
                return False
        return True
    
    pat_info_df = pd.merge(cov_df, HLA_df, right_index=True, left_index=True, how="inner")
    df = pd.DataFrame(columns=["TCR", "coef", "se", "pvalue", "tvalue"])
    drop_families = []

    while is_continue(df):
        _, usage_table = counts_to_usage_df(counts_df, drop_families=drop_families)
        tcr_columns = [x for x in vdj_table.columns if x.startswith("TR")]
        res_df = do_ols(pat_info_df, usage_table, ind_var, tcr_columns, cov_cols)
        top_row = res_df.iloc[0]
        if fdr:
            pvalue = top_row['pvalue_fdr']
        else:
            pvalue = top_row['pvalue']
        print(top_row['TCR'], pvalue)
        if len(want_families) == 0:
            if pvalue > 0.05: # get all rows until the top row is no longer significant
                break
        drop_families.append(top_row['TCR'])
        df = df.append(top_row)
        
    df['coef'] = df['coef']*100 # want the coef to be in percentages
    return df

# %%
HLA_df = pd.read_csv("DGN_HLA_df.csv").set_index("patid").apply(lambda x: x > 0).astype("float")
# counts_df = pd.read_csv("DGN_transcript_counts_df.csv", index_col=0, low_memory=False)
# counts_df = counts_df[(counts_df['transcript'].str.startswith("TR"))]
#counts_df = counts_df[(counts_df['transcript'].str.startswith("TRAV")) | (counts_df['transcript'].str.startswith("TRBV"))]
vdj_long, vdj_table = counts_to_usage_df(counts_df, drop_families=[])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transcript'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-bf10ba1e4a96> in <module>
#       3 # counts_df = counts_df[(counts_df['transcript'].str.startswith("TR"))]
#       4 #counts_df = counts_df[(counts_df['transcript'].str.startswith("TRAV")) | (counts_df['transcript'].str.startswith("TRBV"))]
# ----> 5 vdj_long, vdj_table = counts_to_usage_df(counts_df, drop_families=[])
#
# <ipython-input-2-5b4aa714008b> in counts_to_usage_df(counts_df, drop_families)
#       2     df = counts_df
#       3     # split transcripts names (TRAJ24*01) into family (TRAJ24) and subtype (01)
# ----> 4     transcript_family_subtype_df = df["transcript"].str.split("*", n = 1, expand = True).rename(columns={0:"family", 1:"subtype"})
#       5     df = df.copy()
#       6     df.loc[:,'count'] = df['count'].astype(int)
#
# ~/36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transcript'

# %%
mean_usages = vdj_long.groupby("family").mean().rename(columns={"usage_ratio":"usage_percent_mean"}).reset_index()
std_usages = vdj_long.groupby("family").std().rename(columns={"usage_ratio":"usage_percent_std"}).reset_index()
mean_std_usages = pd.merge(mean_usages, std_usages, on="family", how="inner")

# %%
# vdj_long.to_csv("DGN_usage_df_nopseudo.csv", index=None)
# vdj_table.to_csv("DGN_usage_table_nopseudo.csv")

# %%
vdj_long['usage_ratio'] = vdj_long['usage_ratio']*100 # only do once!
cov_df = pd.read_csv("DGN_covariates_df.csv").set_index("patid")
cov_df["lane"] = cov_df["fcid"] + "_" + cov_df["lane"].astype("str") # covariates
cov_df = pd.get_dummies(cov_df, columns=['fcid', 'lane'])
pat_info_df = pd.merge(cov_df, HLA_df, right_index=True, left_index=True, how="inner")

# %%
tcr_columns = [x for x in vdj_table.columns if x.startswith("TR")]
fcid_columns = [x for x in cov_df.columns if x.startswith("fcid")]
lane_columns = [x for x in cov_df.columns if x.startswith("lane")]

# %%
# usage_path = "/home/ashteng/TCR_usages/DGN_vdj_usages_table.csv"
# vdj_table.to_csv(usage_path, index=None)

# %%
step_res_df_301_all = do_stepwise_ols(HLA_df, counts_df, cov_df, ind_var="DQB1*03:01", cov_cols=[], fdr=True)
# Out:
# doing 159 tests. out of 895 rows, 306 are DQB1*03:01 > 0
# TRAV13-1 1.8456030487329914e-06
# doing 158 tests. out of 895 rows, 306 are DQB1*03:01 > 0
# TRAV8-5 1.894205159356222e-05
# doing 157 tests. out of 895 rows, 306 are DQB1*03:01 > 0
# TRBV10-3 0.0011034436174010526
# doing 156 tests. out of 895 rows, 306 are DQB1*03:01 > 0
# TRAV2 0.06289516224761228

# %%
step_res_df_301_all
# Out:
#           TCR      coef        se        pvalue    tvalue  pvalue_fdr
# 60   TRAV13-1  0.414876  0.000720  1.160757e-08  5.759419    0.000002
# 95    TRAV8-5 -2.194896  0.004113  1.198864e-07 -5.336985    0.000019
# 113  TRBV10-3  0.185111  0.000410  7.028303e-06  4.519616    0.001103

# %%
step_res_df_301_all_expanded = pd.merge(step_res_df_301_all, mean_std_usages, left_on="TCR", right_on="family", how="inner")

# %%
step_res_df_301_all_expanded
# Out:
#         TCR      coef        se        pvalue    tvalue  pvalue_fdr    family  \
# 0  TRAV13-1  0.414876  0.000720  1.160757e-08  5.759419    0.000002  TRAV13-1
# 1   TRAV8-5 -2.194896  0.004113  1.198864e-07 -5.336985    0.000019   TRAV8-5
# 2  TRBV10-3  0.185111  0.000410  7.028303e-06  4.519616    0.001103  TRBV10-3
#
#    usage_percent_mean  usage_percent_std
# 0            5.393459           1.054466
# 1           17.985501           6.594707
# 2            2.183421           0.589530

# %%
res_df_301_all = do_ols(pat_info_df, vdj_table, ind_var="DQB1*03:01", y_cols=tcr_columns, cov_cols=[])
# Out:
# doing 205 tests. out of 895 rows, 306 are DQB1*03:01 > 0

# %%
res_df_301_all_expanded = pd.merge(res_df_301_all, mean_std_usages, left_on="TCR", right_on="family", how="inner")

# %%
res_df_301_all_expanded.head(10)
# Out:
#           TCR      coef        se        pvalue    tvalue  pvalue_fdr  \
# 0    TRAV13-1  0.004144  0.000720  1.176778e-08  5.757018    0.000002
# 1     TRAV8-5 -0.021526  0.003945  6.295699e-08 -5.456378    0.000006
# 2    TRBV10-3  0.001753  0.000386  6.407027e-06  4.539622    0.000438
# 3     TRAV8-4  0.001788  0.000451  7.943084e-05  3.964494    0.004071
# 4      TRAV20  0.001341  0.000374  3.495513e-04  3.589352    0.014332
# 5      TRAV17  0.001796  0.000521  5.954209e-04  3.446027    0.020344
# 6       TRAJ7  0.001064  0.000336  1.575970e-03  3.170067    0.044612
# 7    TRBV12-3  0.000856  0.000273  1.751016e-03  3.138987    0.044612
# 8  TRAV23/DV6  0.003243  0.001044  1.958559e-03  3.105649    0.044612
# 9    TRBV12-4  0.002808  0.000957  3.426502e-03  2.934492    0.070243
#
#        family  usage_percent_mean  usage_percent_std
# 0    TRAV13-1            0.053900           0.010539
# 1     TRAV8-5            0.179731           0.065830
# 2    TRBV10-3            0.020613           0.005558
# 3     TRAV8-4            0.029961           0.006522
# 4      TRAV20            0.015075           0.005323
# 5      TRAV17            0.024982           0.007902
# 6       TRAJ7            0.009120           0.004869
# 7    TRBV12-3            0.010844           0.003919
# 8  TRAV23/DV6            0.020505           0.014751
# 9    TRBV12-4            0.051195           0.013557

# %%
HLA_df[[x for x in HLA_df.columns if x.startswith("DQA")]].apply(lambda x: x > 0).astype("int").sum()
# Out:
# DQA1*01:01    182
# DQA1*01:02    300
# DQA1*01:03    105
# DQA1*01:04     47
# DQA1*01:05     14
# DQA1*02:01    250
# DQA1*03:01    185
# DQA1*03:02     12
# DQA1*03:03    119
# DQA1*04:01     40
# DQA1*05:01    187
# DQA1*05:03      2
# DQA1*05:05    214
# DQA1*05:09      2
# DQA1*06:01      7
# dtype: int64

# %%
#top_TCR_families = set(step_res_df_301_all['TCR'].values)

# %%
# filt_HLA_df = HLA_df[HLA_df["HLA_DQA1_0101"] > 0.5]
# step_res_df_301_all_DQA10101 = do_stepwise_ols(filt_HLA_df, counts_df, "HLA_DQB1_0301", want_families=top_TCR_families, fdr=False)

# %%
# filt_HLA_df = HLA_df[HLA_df["HLA_DQA1_0102"] > 0.5]
# step_res_df_301_all_DQA10102 = do_stepwise_ols(filt_HLA_df, counts_df, "HLA_DQB1_0301", want_families=top_TCR_families, fdr=False)

# %%
# filt_HLA_df = HLA_df[HLA_df["HLA_DQA1_0501"] > 0.5]
# step_res_df_301_all_DQA10501 = do_stepwise_ols(filt_HLA_df, counts_df, "HLA_DQB1_0301", want_families=top_TCR_families, fdr=False)

# %%
# DQA_columns = [col for col in HLA_df.columns if col.startswith("DQA1")]
# DQB_columns = [col for col in HLA_df.columns if col.startswith("DQB1")]

# HLA_df[HLA_df["DQB1*03:01"] > 0][DQB_columns].sum()

# HLA_df[HLA_df["DQB1*03:01"] == 0][DQB_columns].sum()

# %%
cond_A = HLA_df['DQB1*03:01'] > 0
cond_B = HLA_df['DQB1*03:02'] > 0
filt_HLA_df = HLA_df[(cond_A & ~cond_B) | (cond_B & ~cond_A)]
step_res_df_301_302 = do_stepwise_ols(filt_HLA_df, counts_df, cov_df, ind_var="DQB1*03:01", cov_cols=[], fdr=True)
step_res_df_301_302_expanded = pd.merge(step_res_df_301_302, mean_std_usages, left_on="TCR", right_on="family", how="inner")
# Out:
# doing 91 tests. out of 418 rows, 266 are DQB1*03:01 > 0
# TRBV20-1 0.0008037224697827661
# doing 90 tests. out of 418 rows, 266 are DQB1*03:01 > 0
# TRBV15 0.0005788162382212386
# doing 89 tests. out of 418 rows, 266 are DQB1*03:01 > 0
# TRAV29/DV5 0.005443220023340737
# doing 88 tests. out of 418 rows, 266 are DQB1*03:01 > 0
# TRAV23/DV6 0.014942410435343074
# doing 87 tests. out of 418 rows, 266 are DQB1*03:01 > 0
# TRBV5-6 0.20995037228756946

# %%
step_res_df_301_302_expanded
# Out:
#           TCR      coef        se    pvalue    tvalue  pvalue_fdr      family  \
# 0    TRBV20-1  0.704269  0.001565  0.000009  4.499977    0.000804    TRBV20-1
# 1      TRBV15  0.189745  0.000415  0.000006  4.570250    0.000579      TRBV15
# 2  TRAV29/DV5 -0.310851  0.000768  0.000061 -4.049778    0.005443  TRAV29/DV5
# 3  TRAV23/DV6  0.904373  0.002383  0.000170  3.794656    0.014942  TRAV23/DV6
#
#    usage_percent_mean  usage_percent_std
# 0            7.704853           1.705944
# 1            1.326454           0.676415
# 2            3.493069           0.804180
# 3            2.501602           1.673355

# %%
dqa_cols = [x for x in HLA_df.columns if x.startswith("DQA")]
step_res_df_301_all_cov_dqa = do_stepwise_ols(HLA_df, counts_df, cov_df, ind_var="DQB1*03:01", cov_cols=dqa_cols, fdr=True)
# Out:
# doing 91 tests. out of 895 rows, 306 are DQB1*03:01 > 0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRAV1-1   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.618
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):             0.0581
# Time:                        21:03:52   Log-Likelihood:                 3539.5
# No. Observations:                 895   AIC:                            -7045.
# Df Residuals:                     878   BIC:                            -6963.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0104      0.001     11.974      0.000       0.009       0.012
# DQB1*03:01    -0.0003      0.001     -0.291      0.771      -0.002       0.002
# DQA1*01:01    -0.0005      0.001     -0.936      0.350      -0.002       0.001
# DQA1*01:02    -0.0004      0.001     -0.737      0.461      -0.002       0.001
# DQA1*01:03     0.0005      0.001      0.759      0.448      -0.001       0.002
# DQA1*01:04     0.0013      0.001      1.564      0.118      -0.000       0.003
# DQA1*01:05    -0.0016      0.001     -1.224      0.221      -0.004       0.001
# DQA1*02:01    -0.0001      0.001     -0.197      0.844      -0.001       0.001
# DQA1*03:01    -0.0002      0.001     -0.303      0.762      -0.001       0.001
# DQA1*03:02     0.0013      0.001      0.940      0.347      -0.001       0.004
# DQA1*03:03     0.0009      0.001      0.943      0.346      -0.001       0.003
# DQA1*04:01    -0.0001      0.001     -0.172      0.864      -0.002       0.002
# DQA1*05:01     0.0010      0.001      1.669      0.095      -0.000       0.002
# DQA1*05:03     0.0002      0.003      0.062      0.950      -0.007       0.007
# DQA1*05:05     0.0010      0.001      1.016      0.310      -0.001       0.003
# DQA1*05:09    -0.0032      0.003     -0.948      0.343      -0.010       0.003
# DQA1*06:01    -0.0013      0.002     -0.659      0.510      -0.005       0.003
# ==============================================================================
# Omnibus:                      285.980   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1136.568
# Skew:                           1.466   Prob(JB):                    1.58e-247
# Kurtosis:                       7.677   Cond. No.                         29.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRAV1-2   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.5960
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.889
# Time:                        21:03:52   Log-Likelihood:                 2458.0
# No. Observations:                 895   AIC:                            -4882.
# Df Residuals:                     878   BIC:                            -4800.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.
Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2848258.376
# Skew:                          13.162   Prob(JB):                         0.00
# Kurtosis:                     278.109   Cond. No.                         29.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# TRBV14 0.2922564968020448

# %%
res_df_301_all_cov_dqa = do_ols(pat_info_df, vdj_table, ind_var="DQB1*03:01", y_cols=tcr_columns, cov_cols=['DQA1*05:05', 'DQA1*03:03', 'DQA1*06:01'])
# Out:
# doing 91 tests. out of 895 rows, 306 are DQB1*03:01 > 0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRAV1-1   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.601
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.172
# Time:                        21:17:26   Log-Likelihood:                 3529.7
# No. Observations:                 895   AIC:                            -7049.
# Df Residuals:                     890   BIC:                            -7025.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0104      0.000     53.357      0.000       0.010       0.011
# DQB1*03:01    -0.0004      0.001     -0.389      0.697      -0.002       0.001
# DQA1*05:05     0.0011      0.001      1.243      0.214      -0.001       0.003
# DQA1*03:03     0.0008      0.001      1.050      0.294      -0.001       0.002
# DQA1*06:01    -0.0009      0.002     -0.494      0.621      -0.005       0.003
# ==============================================================================
# Omnibus:                      293.802   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1156.773
# Skew:                           1.514   Prob(JB):                    6.46e-252
# Kurtosis:                       7.674   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRAV1-2   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.2056
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.935
# Time:                        21:17:26   Log-Likelihood:                 2453.6
# No. Observations:                 895   AIC:                            -4897.
# Df Residuals:                     890   BIC:                            -4873.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0333      0.001     51.528      0.000       0.032       0.035
# DQB1*03:01    -0.0003      0.003     -0.094      0.925      -0.006       0.006
# DQA1*05:05    -0.0006      0.003     -0.214      0.830      -0.006       0.005
# DQA1*03:03    -0.0006      0.003     -0.248      0.804      -0.006       0.004
# DQA1*06:01    -0.0009      0.006     -0.136      0.892      -0.013       0.011
# ==============================================================================
# Omnibus:                      270.875   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              822.745
# Skew:                           1.492   Prob(JB):                    2.20e-179
# Kurtosis:                       6.627   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 TRAV10   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9256
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.448
# Time:                        21:17:27   Log-Likelihood:                 3306.5
# No. Observations:                 895   AIC:                            -6603.
# Df Residuals:                     890   BIC:                            -6579.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0159      0.000     63.841      0.000       0.015       0.016
# DQB1*03:01    -0.0020      0.001     -1.710      0.088      -0.004       0.000
# DQA1*05:05     0.0014      0.001      1.264      0.206      -0.001       0.004
# DQA1*03:03     0.0014      0.001      1.419      0.156      -0.001       0.003
# DQA1*06:01     0.0024      0.002      1.010      0.313      -0.002       0.007
# ==============================================================================
# Omnibus:                      992.094   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           101679.614
# Skew:                           5.213   Prob(JB):                         0.00
# Kurtosis:                      54.165   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               TRAV12-1   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     3.142
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):             0.0140
# Time:                        21:17:27   Log-Likelihood:                 2514.6
# No. Observations:                 895   AIC:                            -5019.
# Df Residuals:                     890   BIC:                            -4995.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0427      0.001     70.647      0.000       0.042       0.044
# DQB1*03:01 -2.184e-05      0.003     -0.008      0.994      -0.006       0.005
# DQA1*05:05    -0.0040      0.003     -1.461      0.144      -0.009       0.001
# DQA1*03:03    -0.0006      0.002     -0.240      0.811      -0.005       0.004
# DQA1*06:01     0.0008      0.006      0.138      0.890      -0.011       0.012
# ==============================================================================
# Omnibus:                     1748.632   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3474634.646
# Skew:                          14.152   Prob(JB):                         0.00
# Kurtosis:                     306.930   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               TRAV12-2   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.4526
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.771
# Time:                        21:17:27   Log-Likelihood:                 2465.1
# No. Observations:                 895   AIC:                            -4920.
# Df Residuals:                     890   BIC:                            -4896.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0488      0.001     76.409      0.000       0.048       0.050
# DQB1*03:01     0.0022      0.003      0.736      0.462      -0.004       0.008
# DQA1*05:05    -0.0010      0.003     -0.355      0.723      -0.007       0.005
# DQA1*03:03    -0.0003      0.003     -0.122      0.903      -0.005       0.005
# DQA1*06:01    -0.0035      0.006     -0.572      0.567      -0.016       0.009
# ==============================================================================
# Omnibus:                      995.755   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           136603.376
# Skew:                           5.117   Prob(JB):                         0.00
# Kurtosis:                      62.652   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               TRAV12-3   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                   0.09220
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.985
# Time:                        21:17:27   Log-Likelihood:                 2853.9
# No. Observations:                 895   AIC:                            -5698.
# Df Residuals:                     890   BIC:                            -5674.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0366      0.000     88.395      0.000       0.036       0.037
# DQB1*03:01     0.0005      0.002      0.272      0.786      -0.003       0.004
# DQA1*05:05    -0.0004      0.002     -0.195      0.845      -0.004       0.003
# DQA1*03:03    -0.0001      0.002     -0.083      0.934      -0.003       0.003
# DQA1*06:01    -0.0022      0.004     -0.545      0.586      -0.010       0.006
# ==============================================================================
# Omnibus:                     1491.697   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1454818.128
# Skew:                          10.179   Prob(JB):                         0.00
# Kurtosis:                     199.462   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               TRAV13-1   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     5.063
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           0.000489
# Time:                        21:17:27   Log-Likelihood:                 2687.6
# No. Observations:                 895   AIC:                            -5365.
# Df Residuals:                     890   BIC:                            -5341.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0647      0.000    129.822      0.000       0.064       0.066
# DQB1*03:01     0.0050      0.002      2.144      0.032       0.000       0.010
# DQA1*05:05    -0.0010      0.002     -0.419      0.675      -0.005       0.004
# DQA1*03:03    -0.0035      0.002     -1.741      0.082      -0.007       0.000
# DQA1*06:01     0.0037      0.005      0.760      0.447      -0.006       0.013
# ==============================================================================
# Omnibus:                      505.526   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9458.659
# Skew:                           2.165   Prob(JB):                         0.00
# Kurtosis:                      18.326   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               TRAV13-2   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.4980
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.737
# Time:                        21:17:27   Log-Likelihood:                 3275.7
# No. Observations:                 895   AIC:                            -6541.
# Df Residuals:                     890   BIC:                            -6517.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0264      0.000    102.200      0.000       0.026       0.027
# DQB1*03:01     0.0008      0.001      0.705      0.481      -0.002       0.003
# DQA1*05:05    -0.0004      0.001     -0.347      0.729      -0.003       0.002
# DQA1*03:03    -0.0007      0.001     -0.669      0.504      -0.003       0.001
# DQA1*06:01     0.0018      0.002      0.727      0.467      -0.003       0.007
# ==============================================================================
# Omnibus:                      538.711   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8654.823
# Skew:                           2.428   Prob(JB):                         0.00
# Kurtosis:                      17.440   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             TRAV14/DV4   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     2.908
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):             0.0208
# Time:                        21:17:27   Log-Likelihood:                 2657.0
# No. Observations:                 895   AIC:                            -5304.
# Df Residuals:                     890   BIC:                            -5280.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0279      0.001     54.117      0.000       0.027       0.029
# DQB1*03:01    -0.0012      0.002     -0.498      0.618      -0.006       0.004
# DQA1*05:05     0.0018      0.002      0.760      0.447      -0.003       0.006
# DQA1*03:03     0.0049      0.002      2.338      0.020       0.001       0.009
# DQA1*06:01    -0.0025      0.005     -0.511      0.610      -0.012       0.007
# ==============================================================================
# Omnibus:                      998.866   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           115326.795
# Skew:                           5.224   Prob(JB):                         0.00
# Kurtosis:                      57.620   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 TRAV16   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     2.611
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):             0.0343
# Time:                        21:17:27   Log-Likelihood:                 3413.2
# No. Observations:                 895   AIC:                            -6816.
# Df Residuals:                     890   BIC:                            -6792.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0173      0.000     78.009      0.000       0.017       0.018
# DQB1*03:01     0.0002      0.001      0.221      0.826      -0.002       0.002
# DQA1*05:05    -0.0014      0.001     -1.342      0.180      -0.003       0.001
# DQA1*03:03    -0.0011      0.001     -1.264      0.207      -0.003       0.001
# DQA1*06:01    -0.0003      0.002     -0.157      0.875      -0.005       0.004
# ==============================================================================
# Omnibus:                      750.631   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22530.554
# Skew:                           3.670   Prob(JB):                         0.00
# Kurtosis:                      26.458   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 TRAV17   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     3.741
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):            0.00501
# Time:                        21:17:27   Log-Likelihood:                 2989.1
# No. Observations:                 895   AIC:                            -5968.
# Df Residuals:                     890   BIC:                            -5944.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0299      0.000     84.057      0.000       0.029       0.031
# DQB1*03:01    -0.0010      0.002     -0.622      0.534      -0.004       0.002
# DQA1*05:05     0.0033      0.002      2.050      0.041       0.000       0.007
# DQA1*03:03  9.353e-05      0.001      0.065      0.948      -0.003       0.003
# DQA1*06:01     0.0041      0.003      1.204      0.229      -0.003       0.011
# ==============================================================================
# Omnibus:                      787.860   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35081.944
# Skew:                           3.792   Prob(JB):                         0.00
# Kurtosis:                      32.719   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 TRAV18   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7545
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.555
# Time:                        21:17:27   Log-Likelihood:                 4831.4
# No. Observations:                 895   AIC:                            -9653.
# Df Residuals:                     890   BIC:                            -9629.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0025   4.54e-05     54.593      0.000       0.002       0.003
# DQB1*03:01    -0.0003      0.000     -1.547      0.122      -0.001    8.79e-05
# DQA1*05:05     0.0002      0.000      1.151      0.250      -0.000       0.001
# DQA1*03:03     0.0003      0.000      1.497      0.135   -8.54e-05       0.001
# DQA1*06:01     0.0003      0.000      0.635      0.526      -0.001       0.001
# ==============================================================================
# Omnibus:                      190.611   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              461.781
# Skew:                           1.126   Prob(JB):                    5.32e-101
# Kurtosis:                       5.704   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 TRAV19   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.2485
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.911
# Time:                        21:17:27   Log-Likelihood:                 2738.2
# No. Observations:                 895   AIC:                            -5466.
# Df Residuals:                     890   BIC:                            -5442.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0330      0.000     70.005      0.000       0.032       0.034
# DQB1*03:01    -0.0019      0.002     -0.855      0.393      -0.006       0.002
# DQA1*05:05     0.0021      0.002      0.986      0.325      -0.002       0.006
# DQA1*03:03     0.0014      0.002      0.739      0.460      -0.002       0.005
# DQA1*06:01     0.0008      0.005      0.180      0.857      -0.008       0.010
# ==============================================================================
# Omnibus:                      570.678   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9106.497
# Skew:                           2.639   Prob(JB):                         0.00
# Kurtosis:                      17.709   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  TRAV2   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     5.536
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           0.000210
# Time:                        21:17:27   Log-Likelihood:                 3377.5
# No. Observations:                 895   AIC:                            -6745.
# Df Residuals:                     890   BIC:                            -6721.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.734
# Time:                        21:17:27   Log-Likelihood:                 3101.8
# No. Observations:                 895   AIC:                            -6194.
# Df Residuals:                     890   BIC:                            -6170.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0123      0.000     39.221      0.000       0.012       0.013
# DQB1*03:01    -0.0007      0.001     -0.511      0.610      -0.004       0.002
# DQA1*05:05     0.0006      0.001      0.401      0.688      -0.002       0.003
# DQA1*03:03    -0.0003      0.001     -0.242      0.809      -0.003       0.002
# DQA1*06:01    -0.0015      0.003     -0.484      0.628      -0.007       0.004
# ==============================================================================
# Omnibus:                     1303.938   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           359675.817
# Skew:                           8.219   Prob(JB):                         0.00
# Kurtosis:                      99.823   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 TRAV25   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.1760
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.951
# Time:                        21:17:27   Log-Likelihood:                 3493.4
# No. Observations:                 895   AIC:                            -6977.
# Df Residuals:                     890   BIC:                            -6953.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0149      0.000     73.782      0.000       0.015       0.015
# DQB1*03:01     0.0003      0.001      0.336      0.737      -0.002       0.002
# DQA1*05:05    -0.0006      0.001     -0.619      0.536      -0.002       0.001
# DQA1*03:03    -0.0003      0.001     -0.324      0.746      -0.002       0.001
# DQA1*06:01  3.294e-05      0.002      0.017      0.987      -0.004       0.004
# ==============================================================================
# Omnibus:                      907.802   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            57802.899
# Skew:                           4.649   Prob(JB):                         0.00
# Kurtosis:                      41.257   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               TRAV26-1   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.099
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.356
# Time:                        21:17:27   Log-Likelihood:                 2962.7
# No. Observations:                 895   AIC:                            -5915.
# Df Residuals:                     890   BIC:                            -5891.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0287      0.000     78.364      0.000       0.028       0.029
# DQB1*03:01    -0.0015      0.002     -0.870      0.385      -0.005       0.002
# DQA1*05:05     0.0006      0.002      0.339      0.735      -0.003       0.004
# DQA1*03:03    -0.0003      0.001     -0.171      0.864      -0.003       0.003
# DQA1*06:01    -0.0012      0.004     -0.330      0.742      -0.008       0.006
# ==============================================================================
# Omnibus:                     1023.285   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           250060.593
# Skew:                           5.136   Prob(JB):                         0.00
# Kurtosis:                      84.241   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               TRAV26-2   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.279
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.277
# Time:                        21:17:27   Log-Likelihood:                 3384.6
# No. Observations:                 895   AIC:                            -6759.
# Df Residuals:                     890   BIC:                            -6735.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0159      0.000     69.375      0.000       0.015       0.016
# DQB1*03:01     0.0001      0.001      0.095      0.924      -0.002       0.002
# DQA1*05:05     0.0008      0.001      0.781      0.435      -0.001       0.003
# DQA1*03:03    -0.0003      0.001     -0.352      0.725      -0.002       0.001
# DQA1*06:01     0.0014      0.002      0.631      0.528      -0.003       0.006
# ==============================================================================
# Omnibus:                      520.291   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11603.621
# Skew:                           2.192   Prob(JB):                         0.00
# Kurtosis:                      20.086   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 TRAV27   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                   0.09066
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.985
# Time:                        21:17:27   Log-Likelihood:                 3077.2
# No. Observations:                 895   AIC:                            -6144.
# Df Residuals:                     890   BIC:                            -6121.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0185      0.000     57.321      0.000       0.018       0.019
# DQB1*03:01     0.0003      0.001      0.188      0.851      -0.003       0.003
# DQA1*05:05    -0.0001      0.001     -0.092      0.927      -0.003       0.003
# DQA1*03:03    -0.0004      0.001     -0.339      0.735      -0.003       0.002
# DQA1*06:01    -0.0014      0.003     -0.449      0.653      -0.008       0.005
# ==============================================================================
# Omnibus:                     1806.135   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4505697.008
# Skew:                          15.142   Prob(JB):                         0.00
# Kurtosis:                     349.274   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ...
# Df Residuals:                     890   BIC:                        -1.038e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023   2.99e-05     77.152      0.000       0.002       0.002
# DQB1*03:01    -0.0001      0.000     -0.867      0.386      -0.000       0.000
# DQA1*05:05     0.0002      0.000      1.205      0.229      -0.000       0.000
# DQA1*03:03  3.061e-05      0.000      0.254      0.800      -0.000       0.000
# DQA1*06:01 -1.315e-05      0.000     -0.046      0.964      -0.001       0.001
# ==============================================================================
# Omnibus:                       93.762   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              134.334
# Skew:                           0.772   Prob(JB):                     6.76e-30
# Kurtosis:                       4.103   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRBV7-2   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.1237
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.974
# Time:                        21:17:28   Log-Likelihood:                 2263.4
# No. Observations:                 895   AIC:                            -4517.
# Df Residuals:                     890   BIC:                            -4493.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0661      0.001     82.638      0.000       0.065       0.068
# DQB1*03:01    -0.0013      0.004     -0.349      0.727      -0.009       0.006
# DQA1*05:05     0.0003      0.004      0.095      0.925      -0.007       0.008
# DQA1*03:03     0.0003      0.003      0.099      0.921      -0.006       0.007
# DQA1*06:01     0.0002      0.008      0.029      0.977      -0.015       0.015
# ==============================================================================
# Omnibus:                      156.035   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              634.533
# Skew:                           0.764   Prob(JB):                    1.63e-138
# Kurtosis:                       6.832   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRBV7-3   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8027
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.524
# Time:                        21:17:28   Log-Likelihood:                 2940.3
# No. Observations:                 895   AIC:                            -5871.
# Df Residuals:                     890   BIC:                            -5847.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0219      0.000     58.290      0.000       0.021       0.023
# DQB1*03:01     0.0025      0.002      1.440      0.150      -0.001       0.006
# DQA1*05:05    -0.0029      0.002     -1.673      0.095      -0.006       0.000
# DQA1*03:03    -0.0023      0.002     -1.504      0.133      -0.005       0.001
# DQA1*06:01    -0.0026      0.004     -0.728      0.467      -0.010       0.004
# ==============================================================================
# Omnibus:                      810.855   Durbin-Watson:                   2.181
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            75213.233
# Skew:                           3.677   Prob(JB):                         0.00
# Kurtosis:                      47.304   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRBV7-6   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.3767
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.825
# Time:                        21:17:28   Log-Likelihood:                 3403.0
# No. Observations:                 895   AIC:                            -6796.
# Df Residuals:                     890   BIC:                            -6772.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0091      0.000     40.571      0.000       0.009       0.010
# DQB1*03:01 -6.207e-05      0.001     -0.060      0.953      -0.002       0.002
# DQA1*05:05    -0.0004      0.001     -0.397      0.692      -0.002       0.002
# DQA1*03:03     0.0003      0.001      0.346      0.730      -0.001       0.002
# DQA1*06:01     0.0001      0.002      0.046      0.963      -0.004       0.004
# ==============================================================================
# Omnibus:                     1745.019   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3219757.644
# Skew:                          14.127   Prob(JB):                         0.00
# Kurtosis:                     295.475   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRBV7-7   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.3283
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.859
# Time:                        21:17:28   Log-Likelihood:                 4355.5
# No. Observations:                 895   AIC:                            -8701.
# Df Residuals:                     890   BIC:                            -8677.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0037   7.73e-05     47.750      0.000       0.004       0.004
# DQB1*03:01     0.0002      0.000      0.466      0.641      -0.001       0.001
# DQA1*05:05  -5.42e-05      0.000     -0.153      0.878      -0.001       0.001
# DQA1*03:03  3.831e-05      0.000      0.123      0.902      -0.001       0.001
# DQA1*06:01    -0.0002      0.001     -0.298      0.766      -0.002       0.001
# ==============================================================================
# Omnibus:                     1252.196   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           313016.040
# Skew:                           7.618   Prob(JB):                         0.00
# Kurtosis:                      93.342   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRBV7-8   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.5221
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.720
# Time:                        21:17:29   Log-Likelihood:                 3159.2
# No. Observations:                 895   AIC:                            -6308.
# Df Residuals:                     890   BIC:                            -6284.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0208      0.000     70.694      0.000       0.020       0.021
# DQB1*03:01     0.0004      0.001      0.281      0.779      -0.002       0.003
# DQA1*05:05    -0.0004      0.001     -0.316      0.752      -0.003       0.002
# DQA1*03:03     0.0007      0.001      0.595      0.552      -0.002       0.003
# DQA1*06:01  1.143e-05      0.003      0.004      0.997      -0.006       0.006
# ==============================================================================
# Omnibus:                      818.813   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36461.766
# Skew:                           4.044   Prob(JB):                         0.00
# Kurtosis:                      33.205   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRBV7-9   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.316
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.262
# Time:                        21:17:29   Log-Likelihood:                 2540.3
# No. Observations:                 895   AIC:                            -5071.
# Df Residuals:                     890   BIC:                            -5047.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0598      0.001    101.785      0.000       0.059       0.061
# DQB1*03:01     0.0025      0.003      0.910      0.363      -0.003       0.008
# DQA1*05:05    -0.0002      0.003     -0.062      0.950      -0.005       0.005
# DQA1*03:03    -0.0002      0.002     -0.070      0.945      -0.005       0.004
# DQA1*06:01    -0.0015      0.006     -0.272      0.785      -0.013       0.010
# ==============================================================================
# Omnibus:                      764.706   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28410.573
# Skew:                           3.687   Prob(JB):                         0.00
# Kurtosis:                      29.598   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  TRBV9   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.3938
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):              0.813
# Time:                        21:17:29   Log-Likelihood:                 2787.3
# No. Observations:                 895   AIC:                            -5565.
# Df Residuals:                     890   BIC:                            -5541.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0252      0.000     56.640      0.000       0.024       0.026
# DQB1*03:01    -0.0003      0.002     -0.133      0.894      -0.004       0.004
# DQA1*05:05  9.876e-05      0.002      0.048      0.961      -0.004       0.004
# DQA1*03:03    -0.0011      0.002     -0.618      0.537      -0.005       0.002
# DQA1*06:01    -0.0004      0.004     -0.103      0.918      -0.009       0.008
# ==============================================================================
# Omnibus:                     1710.017   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3042186.352
# Skew:                          13.493   Prob(JB):                         0.00
# Kurtosis:                     287.341   Cond. No.                         14.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
res_df_301_all_cov_dqa
# Out:
#            TCR      coef        se    pvalue    tvalue  pvalue_fdr
# 55      TRBV14 -0.002686  0.000965  0.005488 -2.783708    0.468746
# 44     TRAV9-2 -0.005595  0.002341  0.017058 -2.389957    0.468746
# 17  TRAV23/DV6  0.007599  0.003233  0.018964  2.350541    0.468746
# 54      TRBV13 -0.003843  0.001673  0.021802 -2.297833    0.468746
# 41     TRAV8-4  0.003195  0.001430  0.025755  2.233629    0.468746
# ..         ...       ...       ...       ...       ...         ...
# 24       TRAV3  0.000057  0.001252  0.963484  0.045795    0.993431
# 80     TRBV6-5  0.000071  0.001772  0.967984  0.040148    0.993431
# 48    TRBV11-1 -0.000031  0.000878  0.971597 -0.035615    0.993431
# 3     TRAV12-1 -0.000022  0.002811  0.993805 -0.007767    0.996673
# 66     TRBV3-1  0.000008  0.001936  0.996673  0.004171    0.996673
#
# [91 rows x 6 columns]

# %%
df1 = pd.merge(step_res_df_301_302, step_res_df_301_601, on="TCR", how="inner", suffixes=('_302', '_601'))
df2 = pd.merge(step_res_df_301_all, df1, on="TCR", how="inner")
res_df = df2[['TCR', 'coef', 'pvalue_fdr', 'coef_302', 'pvalue_302', 'coef_601', 'pvalue_601']]
header = [np.array(["", "03:01 vs non-03:01", "03:01 vs non-03:01", "03:01 vs 03:02", "03:01 vs 03:02", "03:01 vs 06:01", "03:01 vs 06:01"]), 
np.array(["TCR", "coef", "p-value (FDR)", "coef", "p-value (non-FDR)", "coef", "p-value (non-FDR)"])] 
res_df.columns = header

# %%
res_df.to_csv("3_group_coef_pvalues.csv")

# %%
num_rows, num_cols = len(res_df), 3
pvalues_mat = np.zeros((num_rows, num_cols))
coefs_mat = np.zeros((num_rows, num_cols))
tcrs = res_df['TCR'].values

suffixes = ['', '_601', '_302']

for i, suffix in enumerate(suffixes):
    pvalues = res_df['pvalue'+suffix].values
    coefs = res_df['coef'+suffix].values
    pvalues_mat[:,i] = pvalues
    coefs_mat[:,i] = coefs
    
# signed_log_pvalues_mat = -np.log(pvalues_mat)*np.where(coefs_mat > 0, 1, -1)

fig, (ax1) = plt.subplots(sharex=False, sharey=True, figsize=((pvalues_mat.shape[1]//2+3)*2, (pvalues_mat.shape[0]//2)*2))
fig.tight_layout(pad=3.0)
ax1 = sns.heatmap(coefs_mat, cmap='seismic', center=0, cbar_kws={'label': "coef"}, ax=ax1, annot=pvalues_mat)
ax1.set_title("DQB1*03:01 status predicting TCR family expression")
ax1.set_yticklabels(tcrs, rotation=0)
ax1.set_xticklabels(['ALL', '03:01 XOR 06:01', '03:01 XOR 03:02'])
plt.xlabel("Cohort")
plt.ylabel("TCR family")
bottom, top = ax1.get_ylim()
ax1.set_ylim(bottom + 0.5, top - 0.5)

# %%
num_rows, num_cols = len(res_df), 3
pvalues_mat = np.zeros((num_rows, num_cols))
coefs_mat = np.zeros((num_rows, num_cols))
tcrs = res_df['TCR'].values

suffixes = ['', '_601', '_302']

for i, suffix in enumerate(suffixes):
    pvalues = res_df['pvalue'+suffix].values
    coefs = res_df['coef'+suffix].values
    pvalues_mat[:,i] = pvalues
    coefs_mat[:,i] = coefs
    
# signed_log_pvalues_mat = -np.log(pvalues_mat)*np.where(coefs_mat > 0, 1, -1)

fig, (ax1) = plt.subplots(sharex=False, sharey=True, figsize=((pvalues_mat.shape[1]//2+3)*2, (pvalues_mat.shape[0]//2)*2))
fig.tight_layout(pad=3.0)
ax1 = sns.heatmap(coefs_mat, cmap='seismic', center=0, cbar_kws={'label': "coef"}, ax=ax1, annot=pvalues_mat)
ax1.set_title("DQB1*03:01 status predicting TCR family expression")
ax1.set_yticklabels(tcrs, rotation=0)
ax1.set_xticklabels(['ALL', '03:01 XOR 06:01', '03:01 XOR 03:02'])
plt.xlabel("Cohort")
plt.ylabel("TCR family")
bottom, top = ax1.get_ylim()
ax1.set_ylim(bottom + 0.5, top - 0.5)
