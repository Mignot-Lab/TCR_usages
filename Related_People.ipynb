# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# %matplotlib inline

# %%
relatives_path = "/labs/mignot/GenRED.II.autosomalClean.Final.genome"

# %%
relatives_df = pd.read_csv(relatives_path, delim_whitespace=True)

# %%
relatives_df['PI_HAT'].hist()
